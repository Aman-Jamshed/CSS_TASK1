# %% [markdown]
# ## MACHINE LEARNING TASK

# %% [markdown]
# ### Question 1

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv")
df.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %% [markdown]
# ### Question 2

# %%
customer_5 = df.iloc[:,4]
customer_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %% [markdown]
# ### Question 3

# %%
q3 = df[(df['gender']=='Male') & (df['SeniorCitizen']==1) & (df['PaymentMethod']=='Electronic check')]
q3.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV   Male              1      No         No       1           No
# 55  1658-BYGOY   Male              1      No         No      18          Yes
# 57  5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 78  0191-ZHSKZ   Male              1      No         No      30          Yes
# 91  2424-WVHPL   Male              1      No         No       1          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 55               Yes     Fiber optic             No  ...               No
# 57               Yes     Fiber optic             No  ...              Yes
# 78                No             DSL            Yes  ...               No
# 91                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Question 4

# %%
q4 = df[((df['Contract']=='Two year') & (df['PaymentMethod']=='Mailed check') & (df['Churn']=='Yes'))]
q4.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %% [markdown]
# ### Question 5

# %%
import matplotlib.pyplot as plt

# %%
x = df['InternetService'].value_counts().keys().tolist()
y = df['InternetService'].value_counts().tolist()
plt.bar(x,y, color=['g','r','b'])
plt.xlabel("Types of Internet Services")
plt.ylabel("Count Of Customers")
plt.title("Categories of Internet Services")
# Out:
# Text(0.5, 1.0, 'Categories of Internet Services')

# %% [markdown]
# ### Question 6

# %%
x = df['tenure'].values.tolist()
plt.hist(x, bins=30,color='red')
plt.xlabel("Tenure")
# Out:
# Text(0.5, 0, 'Tenure')

# %% [markdown]
# ### Question 7

# %%
x = df['tenure'].values.tolist()
y = df['MonthlyCharges'].values.tolist()
plt.scatter(x,y, marker='.', s=10)
plt.xlabel("Tenure")
plt.ylabel("MonthlyCharges")
# Out:
# Text(0, 0.5, 'MonthlyCharges')
